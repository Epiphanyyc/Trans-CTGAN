# %% [markdown]
# # Tutorial 2: Benchmarks
#
# `synthcity` support comparing the performance of multiple models on some data.
#
# In this tutorial, we will cover how to run benchmarks and which metrics are available.
#
# The available metrics can change on different data loaders or task types.

# %%
# !pip install synthcity
# !pip uninstall -y torchaudio torchdata
# Out:
# Requirement already satisfied: synthcity in e:\qycache\anaconda\envs\llm\lib\site-packages (0.2.11)
# Requirement already satisfied: importlib-metadata in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (8.4.0)
# Requirement already satisfied: pandas>=2.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (2.2.2)
# Requirement already satisfied: torch<2.3,>=2.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.5.1)
# Requirement already satisfied: nflows>=0.14 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.14)
# Requirement already satisfied: numpy<2.0,>=1.20 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.26.4)
# Requirement already satisfied: lifelines<0.30.0,>=0.29.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.29.0)
# Requirement already satisfied: opacus>=1.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.5.2)
# Requirement already satisfied: networkx<3.0,>2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (2.8.8)
# Requirement already satisfied: decaf-synthetic-data>=0.1.6 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.1.6)
# Requirement already satisfied: optuna>=3.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (4.1.0)
# Requirement already satisfied: shap in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.46.0)
# Requirement already satisfied: tenacity in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (8.5.0)
# Requirement already satisfied: tqdm in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (4.66.5)
# Requirement already satisfied: loguru in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.7.2)
# Requirement already satisfied: pydantic<2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.10.19)
# Requirement already satisfied: cloudpickle in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (3.0.0)
# Requirement already satisfied: scipy in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.13.1)
# Requirement already satisfied: xgboost<3.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (2.1.2)
# Requirement already satisfied: geomloss in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.2.6)
# Requirement already satisfied: pgmpy in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.1.26)
# Requirement already satisfied: redis in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (5.2.0)
# Requirement already satisfied: pycox in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.3.0)
# Requirement already satisfied: xgbse>=0.3.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.3.3)
# Requirement already satisfied: pykeops in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (2.2.3)
# Requirement already satisfied: fflows in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.0.3)
# Requirement already satisfied: monai in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (1.4.0)
# Requirement already satisfied: arfpy in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.1.1)
# Requirement already satisfied: tsai in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.3.9)
# Requirement already satisfied: be-great>=0.0.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from synthcity) (0.0.8)
# Requirement already satisfied: datasets>=2.5.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from be-great>=0.0.5->synthcity) (2.21.0)
# Requirement already satisfied: transformers>=4.22.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from be-great>=0.0.5->synthcity) (4.44.2)
# Requirement already satisfied: accelerate>=0.20.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from be-great>=0.0.5->synthcity) (0.34.0)
# Requirement already satisfied: pytorch-lightning<2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from decaf-synthetic-data>=0.1.6->synthcity) (1.9.5)
# Requirement already satisfied: torchtext>=0.10 in e:\qycache\anaconda\envs\llm\lib\site-packages (from decaf-synthetic-data>=0.1.6->synthcity) (0.17.1)
# Requirement already satisfied: matplotlib>=3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (3.9.2)
# Requirement already satisfied: autograd>=1.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (1.7.0)
# Requirement already satisfied: autograd-gamma>=0.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from lifelines<0.30.0,>=0.29.0->synthcity) (1.0.2)
# Requirement already satisfied: tensorboard in e:\qycache\anaconda\envs\llm\lib\site-packages (from nflows>=0.14->synthcity) (2.18.0)
# Requirement already satisfied: opt-einsum>=3.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from opacus>=1.3->synthcity) (3.4.0)
# Requirement already satisfied: alembic>=1.5.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from optuna>=3.1->synthcity) (1.14.0)
# Requirement already satisfied: colorlog in e:\qycache\anaconda\envs\llm\lib\site-packages (from optuna>=3.1->synthcity) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from optuna>=3.1->synthcity) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from optuna>=3.1->synthcity) (2.0.32)
# Requirement already satisfied: PyYAML in e:\qycache\anaconda\envs\llm\lib\site-packages (from optuna>=3.1->synthcity) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pandas>=2.1->synthcity) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pandas>=2.1->synthcity) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pandas>=2.1->synthcity) (2024.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pydantic<2.0->synthcity) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from scikit-learn>=1.2->synthcity) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from scikit-learn>=1.2->synthcity) (3.5.0)
# Requirement already satisfied: filelock in e:\qycache\anaconda\envs\llm\lib\site-packages (from torch<2.3,>=2.1->synthcity) (3.15.4)
# Requirement already satisfied: sympy in e:\qycache\anaconda\envs\llm\lib\site-packages (from torch<2.3,>=2.1->synthcity) (1.13.1)
# Requirement already satisfied: jinja2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from torch<2.3,>=2.1->synthcity) (3.1.4)
# Requirement already satisfied: fsspec in e:\qycache\anaconda\envs\llm\lib\site-packages (from torch<2.3,>=2.1->synthcity) (2024.6.1)
# Requirement already satisfied: colorama in e:\qycache\anaconda\envs\llm\lib\site-packages (from tqdm->synthcity) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from importlib-metadata->synthcity) (3.20.1)
# Requirement already satisfied: win32-setctime>=1.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from loguru->synthcity) (1.1.0)
# Requirement already satisfied: pyparsing in e:\qycache\anaconda\envs\llm\lib\site-packages (from pgmpy->synthcity) (3.1.4)
# Requirement already satisfied: statsmodels in e:\qycache\anaconda\envs\llm\lib\site-packages (from pgmpy->synthcity) (0.14.4)
# Requirement already satisfied: google-generativeai in e:\qycache\anaconda\envs\llm\lib\site-packages (from pgmpy->synthcity) (0.8.3)
# Requirement already satisfied: torchtuples>=0.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (0.2.2)
# Requirement already satisfied: feather-format>=0.4.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (0.4.1)
# Requirement already satisfied: h5py>=2.9.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (3.12.1)
# Requirement already satisfied: numba>=0.44 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (0.60.0)
# Requirement already satisfied: requests>=2.22.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (2.32.3)
# Requirement already satisfied: py7zr>=0.11.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pycox->synthcity) (0.22.0)
# Requirement already satisfied: pybind11 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pykeops->synthcity) (2.13.6)
# Requirement already satisfied: keopscore==2.2.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pykeops->synthcity) (2.2.3)
# Requirement already satisfied: async-timeout>=4.0.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from redis->synthcity) (4.0.3)
# Requirement already satisfied: slicer==0.0.8 in e:\qycache\anaconda\envs\llm\lib\site-packages (from shap->synthcity) (0.0.8)
# Requirement already satisfied: fastai>=2.7.14 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tsai->synthcity) (2.7.18)
# Requirement already satisfied: pyts>=0.12.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tsai->synthcity) (0.13.0)
# Requirement already satisfied: imbalanced-learn>=0.11.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tsai->synthcity) (0.12.4)
# Requirement already satisfied: psutil>=5.4.8 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tsai->synthcity) (6.0.0)
# Requirement already satisfied: huggingface-hub>=0.21.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from accelerate>=0.20.1->be-great>=0.0.5->synthcity) (0.24.6)
# Requirement already satisfied: safetensors>=0.4.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from accelerate>=0.20.1->be-great>=0.0.5->synthcity) (0.4.4)
# Requirement already satisfied: Mako in e:\qycache\anaconda\envs\llm\lib\site-packages (from alembic>=1.5.0->optuna>=3.1->synthcity) (1.3.6)
# Requirement already satisfied: pyarrow>=15.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (0.3.8)
# Requirement already satisfied: xxhash in e:\qycache\anaconda\envs\llm\lib\site-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (3.5.0)
# Requirement already satisfied: multiprocess in e:\qycache\anaconda\envs\llm\lib\site-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (0.70.16)
# Requirement already satisfied: aiohttp in e:\qycache\anaconda\envs\llm\lib\site-packages (from datasets>=2.5.2->be-great>=0.0.5->synthcity) (3.10.5)
# Requirement already satisfied: pip in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (24.2)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (0.0.7)
# Requirement already satisfied: fastcore<1.8,>=1.5.29 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (1.7.20)
# Requirement already satisfied: torchvision>=0.11 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (0.17.1)
# Requirement already satisfied: fastprogress>=0.2.4 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (10.4.0)
# Requirement already satisfied: spacy<4 in e:\qycache\anaconda\envs\llm\lib\site-packages (from fastai>=2.7.14->tsai->synthcity) (3.7.5)
# Requirement already satisfied: interface-meta>=1.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from formulaic>=0.2.2->lifelines<0.30.0,>=0.29.0->synthcity) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from formulaic>=0.2.2->lifelines<0.30.0,>=0.29.0->synthcity) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from matplotlib>=3.0->lifelines<0.30.0,>=0.29.0->synthcity) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in e:\qycache\anaconda\envs\llm\lib\site-packages (from matplotlib>=3.0->lifelines<0.30.0,>=0.29.0->synthcity) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from matplotlib>=3.0->lifelines<0.30.0,>=0.29.0->synthcity) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from matplotlib>=3.0->lifelines<0.30.0,>=0.29.0->synthcity) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from matplotlib>=3.0->lifelines<0.30.0,>=0.29.0->synthcity) (6.4.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from numba>=0.44->pycox->synthcity) (0.43.0)
# Requirement already satisfied: texttable in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (3.21.0)
# Requirement already satisfied: pyzstd>=0.15.9 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (0.16.2)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from py7zr>=0.11.3->pycox->synthcity) (1.1.0)
# Requirement already satisfied: six>=1.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->synthcity) (1.16.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (1.6.0)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pytorch-lightning<2.0->decaf-synthetic-data>=0.1.6->synthcity) (0.11.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from requests>=2.22.0->pycox->synthcity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from requests>=2.22.0->pycox->synthcity) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from requests>=2.22.0->pycox->synthcity) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in e:\qycache\anaconda\envs\llm\lib\site-packages (from requests>=2.22.0->pycox->synthcity) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in e:\qycache\anaconda\envs\llm\lib\site-packages (from sqlalchemy>=1.4.2->optuna>=3.1->synthcity) (3.0.3)
# Collecting torchdata==0.7.1 (from torchtext>=0.10->decaf-synthetic-data>=0.1.6->synthcity)
#   Using cached torchdata-0.7.1-cp39-cp39-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: regex!=2019.12.17 in e:\qycache\anaconda\envs\llm\lib\site-packages (from transformers>=4.22.1->be-great>=0.0.5->synthcity) (2024.7.24)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in e:\qycache\anaconda\envs\llm\lib\site-packages (from transformers>=4.22.1->be-great>=0.0.5->synthcity) (0.19.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-generativeai->pgmpy->synthcity) (0.6.10)
# Requirement already satisfied: google-api-core in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-generativeai->pgmpy->synthcity) (2.23.0)
# Requirement already satisfied: google-api-python-client in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-generativeai->pgmpy->synthcity) (2.154.0)
# Requirement already satisfied: google-auth>=2.15.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-generativeai->pgmpy->synthcity) (2.36.0)
# Requirement already satisfied: protobuf in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-generativeai->pgmpy->synthcity) (5.28.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy->synthcity) (1.25.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from jinja2->torch<2.3,>=2.1->synthcity) (2.1.5)
# Requirement already satisfied: patsy>=0.5.6 in e:\qycache\anaconda\envs\llm\lib\site-packages (from statsmodels->pgmpy->synthcity) (1.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from sympy->torch<2.3,>=2.1->synthcity) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (1.68.0)
# Requirement already satisfied: markdown>=2.6.8 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (72.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from tensorboard->nflows>=0.14->synthcity) (3.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from aiohttp->datasets>=2.5.2->be-great>=0.0.5->synthcity) (1.9.7)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-api-core->google-generativeai->pgmpy->synthcity) (1.66.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy->synthcity) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy->synthcity) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-auth>=2.15.0->google-generativeai->pgmpy->synthcity) (4.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (0.12.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from spacy<4->fastai>=2.7.14->tsai->synthcity) (3.5.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy->synthcity) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy->synthcity) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-api-python-client->google-generativeai->pgmpy->synthcity) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy->synthcity) (1.68.0)
# Requirement already satisfied: language-data>=1.2 in e:\qycache\anaconda\envs\llm\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in e:\qycache\anaconda\envs\llm\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy->synthcity) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in e:\qycache\anaconda\envs\llm\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.7.14->tsai->synthcity) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4->fastai>=2.7.14->tsai->synthcity) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (13.8.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (7.0.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\qycache\anaconda\envs\llm\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in e:\qycache\anaconda\envs\llm\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai->synthcity) (0.1.2)
# Using cached torchdata-0.7.1-cp39-cp39-win_amd64.whl (1.3 MB)
# Installing collected packages: torchdata
# Successfully installed torchdata-0.7.1
# Found existing installation: torchdata 0.7.1
# Uninstalling torchdata-0.7.1:
#   Successfully uninstalled torchdata-0.7.1
# WARNING: Skipping torchaudio as it is not installed.

# %%
# stdlib
import sys
import warnings

warnings.filterwarnings("ignore")

# third party
from sklearn.datasets import load_iris

# synthcity absolute
import synthcity.logger as log
from synthcity.plugins import Plugins
from synthcity.plugins.core.dataloader import GenericDataLoader

X, y = load_iris(return_X_y=True, as_frame=True)
X["target"] = y

loader = GenericDataLoader(X, target_column="target", sensitive_columns=[])

loader.dataframe()
# Out:
# [KeOps] Warning : Cuda libraries were not detected on the system or could not be loaded ; using cpu only mode
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## List the available generative models

# %%
# synthcity absolute
from synthcity.plugins import Plugins

plugins = Plugins().list()

plugins
# Out:
# [2024-11-24T20:32:45.787282+0800][1508][CRITICAL] module disabled: e:\qycache\anaconda\envs\LLM\lib\site-packages\synthcity\plugins\generic\plugin_goggle.py
# ['dpgan',
#  'adsgan',
#  'marginal_distributions',
#  'bayesian_network',
#  'survival_gan',
#  'timegan',
#  'privbayes',
#  'decaf',
#  'survae',
#  'fflows',
#  'survival_ctgan',
#  'survival_nflow',
#  'ddpm',
#  'ctgan',
#  'uniform_sampler',
#  'nflow',
#  'timevae',
#  'aim',
#  'great',
#  'image_adsgan',
#  'image_cgan',
#  'tvae',
#  'pategan',
#  'arf',
#  'radialgan',
#  'rtvae',
#  'dummy_sampler']

# %% [markdown]
# ## Benchmarking metrics
#
# | **Metric**                                         | **Description**                                                                                                            |
# |----------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------|
# | sanity.data\_mismatch.score                        | Data types mismatch between the real//synthetic features                                                                   |
# | sanity.common\_rows\_proportion.score              | Real data copy-paste in the synthetic data                                                                                 |
# | sanity.nearest\_syn\_neighbor\_distance.mean       | Computes the \textless{}reduction\textgreater{}(distance) from the real data to the closest neighbor in the synthetic data |
# | sanity.close\_values\_probability.score            | the probability of close values between the real and synthetic data.                                                       |
# | sanity.distant\_values\_probability.score          | the probability of distant values between the real and synthetic data.                                                     |
# | stats.jensenshannon\_dist.marginal                 | the average Jensen-Shannon distance                                                                                        |
# | stats.chi\_squared\_test.marginal                  | the one-way chi-square test.                                                                                               |
# | stats.feature\_corr.joint                          | the correlation/strength-of-association of features in data-set with both categorical and continuous features              |
# | stats.inv\_kl\_divergence.marginal                 | the average inverse of the Kullback–Leibler Divergence metric.                                                             |
# | stats.ks\_test.marginal                            | the Kolmogorov-Smirnov test for goodness of fit.                                                                           |
# | stats.max\_mean\_discrepancy.joint                 | Empirical maximum mean discrepancy. The lower the result the more evidence that distributions are the same.                |
# | stats.prdc.precision                               | precision between the two manifolds                                                                                        |
# | stats.prdc.recall                                  | recall between the two manifolds                                                                                           |
# | stats.prdc.density                                 | density between the two manifolds                                                                                          |
# | stats.prdc.coverage                                | coverage between the two manifolds                                                                                         |
# | stats.alpha\_precision.delta\_precision\_alpha\_OC | Delta precision                                                                                                            |
# | stats.alpha\_precision.delta\_coverage\_beta\_OC   | Delta coverage                                                                                                             |
# | stats.alpha\_precision.authenticity\_OC            | Authetnticity                                                                                                              |
# | performance.linear\_model.gt.aucroc              | Train on real, test on the test real data using LogisticRegression: AUCROC                                                             |
# | performance.linear\_model.syn\_id.aucroc         | Train on synthetic, test on the train real data using LogisticRegression: AUCROC                                                       |
# | performance.linear\_model.syn\_ood.aucroc        | Train on synthetic, test on the test real data using LogisticRegression: AUCROC                                                        |
# | performance.mlp.gt.aucroc                        | Train on real, test on the test real data using NN: AUCROC                                                                |
# | performance.mlp.syn\_id.aucroc                    | Train on synthetic, test on the train real data using NN: AUCROC                                                          |
# | performance.mlp.syn\_ood.aucroc                   | Train on synthetic, test on the test real data using NN: AUCROC                                                           |
# | performance.xgb.gt.aucroc                         | Train on real, test on the test real data using XGB: AUCROC                                                               |
# | performance.xgb.syn\_id.aucroc                    | Train on synthetic, test on the train real data using XGB: AUCROC                                                         |
# | performance.xgb.syn\_ood.aucroc                   | Train on synthetic, test on the test real data using XGB: AUCROC                                                          |
# | performance.feat\_rank\_distance.corr              | Correlation for the rank distances between the feature importance on real and synthetic data                               |
# | performance.feat\_rank\_distance.pvalue            | p-vale for the rank distances between the feature importance on real and synthetic data                                    |
# | detection.detection\_xgb.mean                      | The average AUCROC score for detecting synthetic data using an XGBoost.                                                    |
# | detection.detection\_mlp.mean                      | The average AUCROC score for detecting synthetic data using a NN.                                                          |
# | detection.detection\_gmm.mean                      | The average AUCROC score for detecting synthetic data using a GMM.                                                         |
# | privacy.delta-presence.score                       | the maximum re-identification probability on the real dataset from the synthetic dataset.                                  |
# | privacy.k-anonymization.gt                         | the k-anon for the real data                                                                                               |
# | privacy.k-anonymization.syn                        | the k-anon for the synthetic data                                                                                          |
# | privacy.k-map.score                                | the minimum value k that satisfies the k-map rule.                                                                         |
# | privacy.distinct l-diversity.gt                    | the l-diversity for the real data                                                                                          |
# | privacy.distinct l-diversity.syn                   | the l-diversity for the synthetic data                                                                                     |
# | privacy.identifiability\_score.score               | the re-identification score on the real dataset from the synthetic dataset.                                                |

# %% [markdown]
# ## Benchmark the quality of plugins

# %%
# synthcity absolute
from synthcity.benchmark import Benchmarks

score = Benchmarks.evaluate(
    [("uniform_sampler", "uniform_sampler", {})],
    loader,
    synthetic_size=len(X),
    repeats=1,
)

# %%
Benchmarks.print(score)
# Out:
# Plugin : uniform_sampler
#                                                      min        max  \
# sanity.data_mismatch.score                      0.166667   0.166667
# sanity.common_rows_proportion.score             0.000000   0.000000
# sanity.nearest_syn_neighbor_distance.mean       0.526560   0.526560
# sanity.close_values_probability.score           0.200000   0.200000
# sanity.distant_values_probability.score         0.233333   0.233333
# stats.jensenshannon_dist.marginal               0.031286   0.031286
# stats.chi_squared_test.marginal                 0.795143   0.795143
# stats.inv_kl_divergence.marginal                0.652426   0.652426
# stats.ks_test.marginal                          0.813333   0.813333
# stats.max_mean_discrepancy.joint                0.203070   0.203070
# stats.wasserstein_dist.joint                    0.242662   0.242662
# stats.prdc.precision                            0.466667   0.466667
# stats.prdc.recall                               0.866667   0.866667
# stats.prdc.density                              0.293333   0.293333
# stats.prdc.coverage                             0.433333   0.433333
# performance.linear_model.gt                     1.000000   1.000000
# performance.linear_model.syn_id                 0.760417   0.760417
# performance.linear_model.syn_ood                0.777778   0.777778
# performance.mlp.gt                              0.647135   0.647135
# performance.mlp.syn_id                          0.458333   0.458333
# performance.mlp.syn_ood                         0.500000   0.500000
# performance.xgb.gt                              0.955729   0.955729
# performance.xgb.syn_id                          0.494792   0.494792
# performance.xgb.syn_ood                         0.652778   0.652778
# performance.linear_model_augmentation.gt        1.000000   1.000000
# performance.linear_model_augmentation.aug_ood   0.777778   0.777778
# performance.mlp_augmentation.gt                 0.647135   0.647135
# performance.mlp_augmentation.aug_ood            0.500000   0.500000
# performance.xgb_augmentation.gt                 0.955729   0.955729
# performance.xgb_augmentation.aug_ood            0.652778   0.652778
# performance.feat_rank_distance.corr            -0.601634  -0.601634
# performance.feat_rank_distance.pvalue           0.000915   0.000915
# detection.detection_xgb.mean                    0.953333   0.953333
# detection.detection_mlp.mean                    0.276667   0.276667
# detection.detection_gmm.mean                    0.531667   0.531667
# detection.detection_linear.mean                 0.550000   0.550000
# privacy.delta-presence.score                    1.000000   1.000000
# privacy.k-anonymization.gt                     10.000000  10.000000
# privacy.k-anonymization.syn                    14.000000  14.000000
# privacy.k-map.score                            10.000000  10.000000
# privacy.distinct l-diversity.gt                10.000000  10.000000
# privacy.distinct l-diversity.syn               14.000000  14.000000
#
#                                                     mean  stddev     median  \
# sanity.data_mismatch.score                      0.166667     0.0   0.166667
# sanity.common_rows_proportion.score             0.000000     0.0   0.000000
# sanity.nearest_syn_neighbor_distance.mean       0.526560     0.0   0.526560
# sanity.close_values_probability.score           0.200000     0.0   0.200000
# sanity.distant_values_probability.score         0.233333     0.0   0.233333
# stats.jensenshannon_dist.marginal               0.031286     0.0   0.031286
# stats.chi_squared_test.marginal                 0.795143     0.0   0.795143
# stats.inv_kl_divergence.marginal                0.652426     0.0   0.652426
# stats.ks_test.marginal                          0.813333     0.0   0.813333
# stats.max_mean_discrepancy.joint                0.203070     0.0   0.203070
# stats.wasserstein_dist.joint                    0.242662     0.0   0.242662
# stats.prdc.precision                            0.466667     0.0   0.466667
# stats.prdc.recall                               0.866667     0.0   0.866667
# stats.prdc.density                              0.293333     0.0   0.293333
# stats.prdc.coverage                             0.433333     0.0   0.433333
# performance.linear_model.gt                     1.000000     0.0   1.000000
# performance.linear_model.syn_id                 0.760417     0.0   0.760417
# performance.linear_model.syn_ood                0.777778     0.0   0.777778
# performance.mlp.gt                              0.647135     0.0   0.647135
# performance.mlp.syn_id                          0.458333     0.0   0.458333
# performance.mlp.syn_ood                         0.500000     0.0   0.500000
# performance.xgb.gt                              0.955729     0.0   0.955729
# performance.xgb.syn_id                          0.494792     0.0   0.494792
# performance.xgb.syn_ood                         0.652778     0.0   0.652778
# performance.linear_model_augmentation.gt        1.000000     0.0   1.000000
# performance.linear_model_augmentation.aug_ood   0.777778     0.0   0.777778
# performance.mlp_augmentation.gt                 0.647135     0.0   0.647135
# performance.mlp_augmentation.aug_ood            0.500000     0.0   0.500000
# performance.xgb_augmentation.gt                 0.955729     0.0   0.955729
# performance.xgb_augmentation.aug_ood            0.652778     0.0   0.652778
# performance.feat_rank_distance.corr             0.001000     0.0  -0.601634
# performance.feat_rank_distance.pvalue           0.001000     0.0   0.000915
# detection.detection_xgb.mean                    0.953333     0.0   0.953333
# detection.detection_mlp.mean                    0.276667     0.0   0.276667
# detection.detection_gmm.mean                    0.531667     0.0   0.531667
# detection.detection_linear.mean                 0.550000     0.0   0.550000
# privacy.delta-presence.score                    1.000000     0.0   1.000000
# privacy.k-anonymization.gt                     10.000000     0.0  10.000000
# privacy.k-anonymization.syn                    14.000000     0.0  14.000000
# privacy.k-map.score                            10.000000     0.0  10.000000
# privacy.distinct l-diversity.gt                10.000000     0.0  10.000000
# privacy.distinct l-diversity.syn               14.000000     0.0  14.000000
#
#                                                iqr rounds errors  durations
# sanity.data_mismatch.score                     0.0      1      0       0.00
# sanity.common_rows_proportion.score            0.0      1      0       0.00
# sanity.nearest_syn_neighbor_distance.mean      0.0      1      0       0.00
# sanity.close_values_probability.score          0.0      1      0       0.00
# sanity.distant_values_probability.score        0.0      1      0       0.00
# stats.jensenshannon_dist.marginal              0.0      1      0       0.00
# stats.chi_squared_test.marginal                0.0      1      0       0.00
# stats.inv_kl_divergence.marginal               0.0      1      0       0.00
# stats.ks_test.marginal                         0.0      1      0       0.00
# stats.max_mean_discrepancy.joint               0.0      1      0       0.00
# stats.wasserstein_dist.joint                   0.0      1      0       0.00
# stats.prdc.precision                           0.0      1      0       0.00
# stats.prdc.recall                              0.0      1      0       0.00
# stats.prdc.density                             0.0      1      0       0.00
# stats.prdc.coverage                            0.0      1      0       0.00
# performance.linear_model.gt                    0.0      1      0       0.00
# performance.linear_model.syn_id                0.0      1      0       0.00
# performance.linear_model.syn_ood               0.0      1      0       0.00
# performance.mlp.gt                             0.0      1      0       0.00
# performance.mlp.syn_id                         0.0      1      0       0.00
# performance.mlp.syn_ood                        0.0      1      0       0.00
# performance.xgb.gt                             0.0      1      0       0.00
# performance.xgb.syn_id                         0.0      1      0       0.00
# performance.xgb.syn_ood                        0.0      1      0       0.00
# performance.linear_model_augmentation.gt       0.0      1      0       0.00
# performance.linear_model_augmentation.aug_ood  0.0      1      0       0.00
# performance.mlp_augmentation.gt                0.0      1      0       0.00
# performance.mlp_augmentation.aug_ood           0.0      1      0       0.00
# performance.xgb_augmentation.gt                0.0      1      0       0.00
# performance.xgb_augmentation.aug_ood           0.0      1      0       0.00
# performance.feat_rank_distance.corr            0.0      1      0       0.01
# performance.feat_rank_distance.pvalue          0.0      1      0       0.01
# detection.detection_xgb.mean                   0.0      1      0       0.00
# detection.detection_mlp.mean                   0.0      1      0       0.00
# detection.detection_gmm.mean                   0.0      1      0       0.00
# detection.detection_linear.mean                0.0      1      0       0.00
# privacy.delta-presence.score                   0.0      1      0       0.00
# privacy.k-anonymization.gt                     0.0      1      0       0.00
# privacy.k-anonymization.syn                    0.0      1      0       0.00
# privacy.k-map.score                            0.0      1      0       0.00
# privacy.distinct l-diversity.gt                0.0      1      0       0.00
# privacy.distinct l-diversity.syn               0.0      1      0       0.00

# %%
Benchmarks.highlight(score)
# Out:
#                                                uniform_sampler
# sanity.data_mismatch.score                            0.166667
# sanity.common_rows_proportion.score                   0.000000
# sanity.nearest_syn_neighbor_distance.mean             0.526560
# sanity.close_values_probability.score                 0.200000
# sanity.distant_values_probability.score               0.233333
# stats.jensenshannon_dist.marginal                     0.031286
# stats.chi_squared_test.marginal                       0.795143
# stats.inv_kl_divergence.marginal                      0.652426
# stats.ks_test.marginal                                0.813333
# stats.max_mean_discrepancy.joint                      0.203070
# stats.wasserstein_dist.joint                          0.242662
# stats.prdc.precision                                  0.466667
# stats.prdc.recall                                     0.866667
# stats.prdc.density                                    0.293333
# stats.prdc.coverage                                   0.433333
# performance.linear_model.gt                           1.000000
# performance.linear_model.syn_id                       0.760417
# performance.linear_model.syn_ood                      0.777778
# performance.mlp.gt                                    0.647135
# performance.mlp.syn_id                                0.458333
# performance.mlp.syn_ood                               0.500000
# performance.xgb.gt                                    0.955729
# performance.xgb.syn_id                                0.494792
# performance.xgb.syn_ood                               0.652778
# performance.linear_model_augmentation.gt              1.000000
# performance.linear_model_augmentation.aug_ood         0.777778
# performance.mlp_augmentation.gt                       0.647135
# performance.mlp_augmentation.aug_ood                  0.500000
# performance.xgb_augmentation.gt                       0.955729
# performance.xgb_augmentation.aug_ood                  0.652778
# performance.feat_rank_distance.corr                   0.001000
# performance.feat_rank_distance.pvalue                 0.001000
# detection.detection_xgb.mean                          0.953333
# detection.detection_mlp.mean                          0.276667
# detection.detection_gmm.mean                          0.531667
# detection.detection_linear.mean                       0.550000
# privacy.delta-presence.score                          1.000000
# privacy.k-anonymization.gt                           10.000000
# privacy.k-anonymization.syn                          14.000000
# privacy.k-map.score                                  10.000000
# privacy.distinct l-diversity.gt                      10.000000
# privacy.distinct l-diversity.syn                     14.000000

# %% [markdown]
# ## Congratulations!
#
# Congratulations on completing this notebook tutorial! If you enjoyed this and would like to join the movement towards Machine learning and AI for medicine, you can do so in the following ways!
#
# ### Star [Synthcity](https://github.com/vanderschaarlab/synthcity) on GitHub
#
# - The easiest way to help our community is just by starring the Repos! This helps raise awareness of the tools we're building.
#
#
# ### Checkout other projects from vanderschaarlab
# - [HyperImpute](https://github.com/vanderschaarlab/hyperimpute)
# - [AutoPrognosis](https://github.com/vanderschaarlab/autoprognosis)
